# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
creditcard_data=pd.read_csv('creditcard.csv')

# %%
creditcard_data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
creditcard_data.Class.value_counts()

# %%
creditcard_data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...         V21       V22       V23       V24  \
# ...

# %%
pd._libs.algos.is_monotonic_float64(creditcard_data.Time.values, False)[0]
# Out:
# True

# %%
creditcard_data.shape
# Out:
# (284807, 31)

# %%
creditcard_data.Time.max()
# Out:
# 172792.0

# %%
creditcard_data.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
creditcard_data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
class0_data=creditcard_data.loc[creditcard_data['Class']==0]

# %%
print('mean class 0 -',class0_data.Amount.mean())
print('min class 0-',class0_data.Amount.min())
print('max class 0-',class0_data.Amount.max())
print('variance class 0-',class0_data.Amount.var())
print('std dev class 0-',np.sqrt(class0_data.Amount.var()))
# Out:
# mean class 0 - 88.29102242225574
# min class 0- 0.0
# max class 0- 25691.16
# variance class 0- 62552.557157310206
# std dev class 0- 250.10509222586853

# %%
class1_data=creditcard_data.loc[creditcard_data['Class']==1]

# %%
print('mean class 1 -',class1_data.Amount.mean())
print('min class 1 -',class1_data.Amount.min())
print('max class 1 -',class1_data.Amount.max())
print('variance class 1 -',class1_data.Amount.var())
print('std dev class 1 -',np.sqrt(class1_data.Amount.var()))
# Out:
# mean class 1 - 122.21132113821133
# min class 1 - 0.0
# max class 1 - 2125.87
# variance class 1 - 65886.31049132637
# std dev class 1 - 256.68328829771207

# %%
class1_data.Amount.mean()
# Out:
# 122.21132113821133

# %%
class1_data.Time.head(5)
# Out:
# 541      406.0
# 623      472.0
# 4920    4462.0
# 6108    6986.0
# 6329    7519.0
# Name: Time, dtype: float64

# %%
plt.rcParams['figure.figsize']=(15,15)

# %%
plt.scatter(class1_data.Time, class1_data.Amount, color='b')
plt.show()

# %%
class1_data.Amount.max()
# Out:
# 2125.87

# %%
plt.rcParams['figure.figsize']=(10,10)
plt.subplot(121)
plt.ylabel('Frequency')
plt.xlabel('Amount')
plt.title('Fraud transactions')
plt.hist(class1_data.Amount) #title='Plot describing fraudulent dist of transactions')
plt.subplot(122)
plt.hist(class0_data.Amount[class0_data['Amount']<=2125.87])#,title='Plot describing normal dist of transactions')
plt.ylabel('Frequency')
plt.xlabel('Amount')
plt.title('Normal transactions')
plt.subplots_adjust(left=2, right=3)
plt.show()

# %%
plt.rcParams['figure.figsize']=(10,10)
plt.subplot(121)
plt.ylabel('Frequency')
plt.xlabel('Time')
plt.title('Fraud transactions')
plt.hist(class1_data.Time) #title='Plot describing fraudulent dist of transactions')
plt.subplot(122)
plt.hist(class0_data.Time)#[class0_data['Amount']<=2125.87])#,title='Plot describing normal dist of transactions')
plt.title('Normal transactions')
plt.ylabel('Frequency')
plt.xlabel('Time')
plt.subplots_adjust(left=2, right=3)
plt.show()

# %% [markdown]
# #### Range below 25000

# %%
print('fraudulent cases below 25000 time units since time=0, ',len(class1_data.loc[class1_data['Time']<25000]))
# Out:
# fraudulent cases below 25000 time units since time=0,  56

# %%
print('normal cases below 25000 time units since time=0, ',len(class0_data.loc[class0_data['Time']<25000]))
print('percentage of fraud, ',len(class1_data.loc[class1_data['Time']<25000])/len(class0_data.loc[class0_data['Time']<25000]))
# Out:
# normal cases below 25000 time units since time=0,  13994
# percentage of fraud,  0.004001715020723167

# %% [markdown]
# #### Range 25000-50000

# %%
print('fraudulent cases greater than 25000 and below 50000 time units since time=0, ',len(class1_data.loc[(class1_data['Time']>=25000) & (class1_data['Time']<50000)]))
# Out:
# fraudulent cases greater than 25000 and below 50000 time units since time=0,  108

# %%
print('normal cases greater than 25000 and below 50000 time units since time=0, ',len(class0_data.loc[(class0_data['Time']>=25000) & (class0_data['Time']<50000)]))
# Out:
# normal cases greater than 25000 and below 50000 time units since time=0,  47657

# %%
print('percentage of fraud, ',len(class1_data.loc[(class1_data['Time']>=25000) & (class1_data['Time']<50000)])/len(class0_data.loc[(class0_data['Time']>=25000) & (class0_data['Time']<50000)]))
# Out:
# percentage of fraud,  0.002266193843506725

# %% [markdown]
# #### Range 50000-75000

# %%
print('fraudulent cases greater than 50000 and below 75000 time units since time=0, ',len(class1_data.loc[(class1_data['Time']>=50000) & (class1_data['Time']<75000)]))
# Out:
# fraudulent cases greater than 50000 and below 75000 time units since time=0,  80

# %%
print('normal cases greater than 50000 and below 75000 time units since time=0, ',len(class0_data.loc[(class0_data['Time']>=50000) & (class0_data['Time']<75000)]))
# Out:
# normal cases greater than 50000 and below 75000 time units since time=0,  56328

# %%
print('percentage of fraud, ',len(class1_data.loc[(class1_data['Time']>=50000) & (class1_data['Time']<75000)])/len(class0_data.loc[(class0_data['Time']>=50000) & (class0_data['Time']<75000)]))
# Out:
# percentage of fraud,  0.0014202528049992898

# %% [markdown]
# #### Range 75000-100000

# %%
print('fraudulent cases greater than 75000 and below 100000 time units since time=0, ',len(class1_data.loc[(class1_data['Time']>=75000) & (class1_data['Time']<100000)]))
# Out:
# fraudulent cases greater than 75000 and below 100000 time units since time=0,  86

# %%
print('normal cases greater than 75000 and below 100000 time units since time=0, ',len(class0_data.loc[(class0_data['Time']>=75000) & (class0_data['Time']<100000)]))
# Out:
# normal cases greater than 75000 and below 100000 time units since time=0,  35449

# %%
print('percentage of fraud, ',len(class1_data.loc[(class1_data['Time']>=75000) & (class1_data['Time']<100000)])/len(class0_data.loc[(class0_data['Time']>=75000) & (class0_data['Time']<100000)]))
# Out:
# percentage of fraud,  0.002426020480126379

# %% [markdown]
# #### Range 100000-125000

# %%
print('fraudulent cases greater than 100000 and below 125000 time units since time=0, ',len(class1_data.loc[(class1_data['Time']>=100000) & (class1_data['Time']<125000)]))
# Out:
# fraudulent cases greater than 100000 and below 125000 time units since time=0,  34

# %%
print('normal cases greater than 100000 and below 125000 time units since time=0, ',len(class0_data.loc[(class0_data['Time']>=100000) & (class0_data['Time']<125000)]))
# Out:
# normal cases greater than 100000 and below 125000 time units since time=0,  27705

# %%
print('percentage of fraud, ',len(class1_data.loc[(class1_data['Time']>=100000) & (class1_data['Time']<125000)])/len(class0_data.loc[(class0_data['Time']>=100000) & (class0_data['Time']<125000)]))
# Out:
# percentage of fraud,  0.0012272153040967335

# %% [markdown]
# #### Range 125000-150000

# %%
print('fraudulent cases greater than 125000 and below 150000 time units since time=0, ',len(class1_data.loc[(class1_data['Time']>=125000) & (class1_data['Time']<150000)]))
# Out:
# fraudulent cases greater than 125000 and below 150000 time units since time=0,  71

# %%
print('normal cases greater than 125000 and below 150000 time units since time=0, ',len(class0_data.loc[(class0_data['Time']>=125000) & (class0_data['Time']<150000)]))
# Out:
# normal cases greater than 125000 and below 150000 time units since time=0,  57625

# %%
print('percentage of fraud, ',len(class1_data.loc[(class1_data['Time']>=125000) & (class1_data['Time']<150000)])/len(class0_data.loc[(class0_data['Time']>=125000) & (class0_data['Time']<150000)]))
# Out:
# percentage of fraud,  0.0012321041214750543

# %% [markdown]
# #### Range 150000-175000

# %%
print('fraudulent cases greater than 150000 and below 175000 time units since time=0, ',len(class1_data.loc[(class1_data['Time']>=150000) & (class1_data['Time']<175000)]))
# Out:
# fraudulent cases greater than 150000 and below 175000 time units since time=0,  57

# %%
print('normal cases greater than 150000 and below 175000 time units since time=0, ',len(class0_data.loc[(class0_data['Time']>=150000) & (class0_data['Time']<175000)]))
# Out:
# normal cases greater than 150000 and below 175000 time units since time=0,  45557

# %%
print('percentage of fraud, ',len(class1_data.loc[(class1_data['Time']>=150000) & (class1_data['Time']<175000)])/len(class0_data.loc[(class0_data['Time']>=150000) & (class0_data['Time']<175000)]))
# Out:
# percentage of fraud,  0.0012511798406391991

# %% [markdown]
# #### Since class 1 constitutes a very small percentage of entire class distribution, it is better to use undersampling/oversampling to understand classification algorithm's performance

# %% [markdown]
# #### Let us perform undersampling first, which is to take a subset of majority class and consider all of minority class

# %%
#print(train_data['label'].value_counts())
from sklearn.utils import resample
class_0subset=creditcard_data[creditcard_data['Class']==0]

hh_df_minority_upsampled = resample(class_0subset, 
                                 replace=True,     # sample with replacement
                                 n_samples=60,    # to match majority class
                                 random_state=123)
hl_df_minority_upsampled = resample(hlsubset, 
                                 replace=True,     # sample with replacement
                                 n_samples=60,    # to match majority class
                                 random_state=123)
hl_df_minority_upsampled.reset_index(drop=True)
hh_df_minority_upsampled.reset_index(drop=True)
mainData=mainData.append(hl_df_minority_upsampled)
mainData=mainData.append(hh_df_minority_upsampled)
mainData=mainData.reset_index(drop=True)
